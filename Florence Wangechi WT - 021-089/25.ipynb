# %% [markdown]
# # Grouping your data

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import matplotlib
matplotlib.rcParams['axes.grid'] = True # show gridlines by default
# %matplotlib inline

import pandas as pd
import pandas_datareader as pdr

# %%
if pd.__version__.startswith('0.23'):
    # this solves an incompatibility between pandas 0.23 and datareader 0.6
    # taken from https://stackoverflow.com/questions/50394873/
    core.common.is_list_like = api.types.is_list_like

from pandas_datareader.wb import download

# %%
# ?download

# %%
YEAR = 2013
GDP_INDICATOR = 'NY.GDP.MKTP.CD'
gdp = download(indicator=GDP_INDICATOR, country=['GB','CN'],
start=YEAR-5, end=YEAR)
gdp = gdp.reset_index()
gdp
# Out:
#            country  year  NY.GDP.MKTP.CD
# 0            China  2013    9.570406e+12
# 1            China  2012    8.532230e+12
# 2            China  2011    7.551500e+12
# 3            China  2010    6.087164e+12
# 4            China  2009    5.101703e+12
# 5            China  2008    4.594307e+12
# 6   United Kingdom  2013    2.783251e+12
# 7   United Kingdom  2012    2.704017e+12
# 8   United Kingdom  2011    2.659882e+12
# 9   United Kingdom  2010    2.481580e+12
# 10  United Kingdom  2009    2.412390e+12
# 11  United Kingdom  2008    2.921432e+12

# %%
gdp.groupby('country')['NY.GDP.MKTP.CD'].aggregate(sum)
# Out:
# country
# China             4.143731e+13
# United Kingdom    1.596255e+13
# Name: NY.GDP.MKTP.CD, dtype: float64

# %%
gdp.groupby('year')['NY.GDP.MKTP.CD'].aggregate(sum)
# Out:
# year
# 2008    7.515739e+12
# 2009    7.514093e+12
# 2010    8.568743e+12
# 2011    1.021138e+13
# 2012    1.123625e+13
# 2013    1.235366e+13
# Name: NY.GDP.MKTP.CD, dtype: float64

# %%
LOCATION='comtrade_milk_uk_monthly_14.csv'

# %%
# LOCATION = 'http://comtrade.un.org/api/get?max=5000&type=C&freq=M&px=HS&ps=2014&r=826&p=all&rg=1%2C2&cc=0401%2C0402&fmt=csv'

# %%
milk = pd.read_csv(LOCATION, dtype={'Commodity Code':str, 'Reporter Code':str})
milk.head(3)
# Out:
#   Classification  Year  Period  Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             HS  2014  201401  January 2014                4             0
# 1             HS  2014  201401  January 2014                4             0
# 2             HS  2014  201401  January 2014                4             0
#
#    Trade Flow Code Trade Flow Reporter Code        Reporter  ...  Qty  \
# 0                1    Imports           826  United Kingdom  ...  NaN
# 1                2    Exports           826  United Kingdom  ...  NaN
# 2                2    Exports           826  United Kingdom  ...  NaN
#
#    Alt Qty Unit Code Alt Qty Unit  Alt Qty  Netweight (kg)  Gross weight (kg)  \
# 0                NaN          NaN      NaN        22404316                NaN
# 1                NaN          NaN      NaN        60497363                NaN
# 2                NaN          NaN      NaN            2520                NaN
#
#    Trade Value (US$)  CIF Trade Value (US$)  FOB Trade Value (US$)  Flag
# 0           21950747                    NaN                    NaN     0
# 1           46923551                    NaN                    NaN     0
# 2               3410                    NaN                    NaN     0
#
# [3 rows x 35 columns]

# %%
COLUMNS = ['Year', 'Period','Trade Flow','Reporter', 'Partner', 'Commodity','Commodity Code','Trade Value (US$)']
milk = milk[COLUMNS]

# %%
milk_world = milk[milk['Partner'] == 'World']
milk_countries = milk[milk['Partner'] != 'World']

# %%
milk_countries.to_csv('countrymilk.csv', index=False)

# %%
load_test = pd.read_csv('countrymilk.csv', dtype={'Commodity Code':str, 'Reporter Code':str})
load_test.head(2)
# Out:
#    Year  Period Trade Flow        Reporter      Partner  \
# 0  2014  201401    Exports  United Kingdom  Afghanistan
# 1  2014  201401    Exports  United Kingdom      Austria
#
#                                            Commodity Commodity Code  \
# 0  Milk and cream, neither concentrated nor sweet...           0401
# 1  Milk and cream, neither concentrated nor sweet...           0401
#
#    Trade Value (US$)
# 0               3410
# 1                316

# %%
milk_imports = milk[milk['Trade Flow'] == 'Imports']
milk_countries_imports = milk_countries[milk_countries['Trade Flow'] == 'Imports']
milk_world_imports=milk_world[milk_world['Trade Flow'] == 'Imports']

# %%
milkImportsInJanuary2014 = milk_countries_imports[milk_countries_imports['Period'] == 201401]
milkImportsInJanuary2014.sort_values('Trade Value (US$)',ascending=False).head(10)
# Out:
#      Year  Period Trade Flow        Reporter      Partner  \
# 23   2014  201401    Imports  United Kingdom      Ireland
# 626  2014  201401    Imports  United Kingdom       France
# 637  2014  201401    Imports  United Kingdom      Ireland
# 650  2014  201401    Imports  United Kingdom  Netherlands
# 629  2014  201401    Imports  United Kingdom      Germany
# 4    2014  201401    Imports  United Kingdom      Belgium
# 612  2014  201401    Imports  United Kingdom      Belgium
# 10   2014  201401    Imports  United Kingdom      Denmark
# 667  2014  201401    Imports  United Kingdom        Spain
# 15   2014  201401    Imports  United Kingdom       France
#
#                                              Commodity Commodity Code  \
# 23   Milk and cream, neither concentrated nor sweet...           0401
# 626          Milk and cream, concentrated or sweetened           0402
# 637          Milk and cream, concentrated or sweetened           0402
# 650          Milk and cream, concentrated or sweetened           0402
# 629          Milk and cream, concentrated or sweetened           0402
# 4    Milk and cream, neither concentrated nor sweet...           0401
# 612          Milk and cream, concentrated or sweetened           0402
# 10   Milk and cream, neither concentrated nor sweet...           0401
# 667          Milk and cream, concentrated or sweetened           0402
# 15   Milk and cream, neither concentrated nor sweet...           0401
#
#      Trade Value (US$)
# 23            10676138
# 626            8020014
# 637            5966962
# 650            4650774
# 629            4545873
# 4              4472349
# 612            3584038
# 10             2233438
# 667            1850097
# 15             1522872

# %% [markdown]
# # Make sure you run all the cell above!

# %% [markdown]
# ## Grouping data
#
# On many occasions, a dataframe may be organised as groups of rows where the group membership is identified based on cell values within one or more 'key' columns. **Grouping** refers to the process whereby rows associated with a particular group are collated so that you can work with just those rows as distinct subsets of the whole dataset.
#
# The number of groups the dataframe will be split into is based on the number of unique values identified within a single key column, or the number of unique combinations of values for two or more key columns.
#
# The `groupby()` method runs down each row in a data frame, splitting the rows into separate groups based on the unique values associated with the key column or columns.
#
# The following is an example of the steps and code needed to split a dataframe.

# %% [markdown]
# ### Grouping the data

# %% [markdown]
# Split the data into two different subsets of data (imports and exports), by grouping on trade flow.

# %%
groups = milk_countries.groupby('Trade Flow')

# %% [markdown]
# Inspect the first few rows associated with a particular group:

# %%
groups.get_group('Imports').head()
# Out:
#     Year  Period Trade Flow        Reporter  Partner  \
# 4   2014  201401    Imports  United Kingdom  Belgium
# 10  2014  201401    Imports  United Kingdom  Denmark
# 15  2014  201401    Imports  United Kingdom   France
# 17  2014  201401    Imports  United Kingdom  Germany
# 23  2014  201401    Imports  United Kingdom  Ireland
#
#                                             Commodity Commodity Code  \
# 4   Milk and cream, neither concentrated nor sweet...           0401
# 10  Milk and cream, neither concentrated nor sweet...           0401
# 15  Milk and cream, neither concentrated nor sweet...           0401
# 17  Milk and cream, neither concentrated nor sweet...           0401
# 23  Milk and cream, neither concentrated nor sweet...           0401
#
#     Trade Value (US$)
# 4             4472349
# 10            2233438
# 15            1522872
# 17            1028700
# 23           10676138

# %% [markdown]
# As well as grouping on a single term, you can create groups based on multiple columns by passing in several column names as a list. For example, generate groups based on commodity code *and* trade flow, and then preview the keys used to define the groups.

# %%
GROUPING_COMMFLOW = ['Commodity Code','Trade Flow']

groups = milk_countries.groupby(GROUPING_COMMFLOW)
groups.groups.keys()
# Out:
# dict_keys([('0401', 'Exports'), ('0401', 'Imports'), ('0402', 'Exports'), ('0402', 'Imports')])

# %% [markdown]
# Retrieve a group based on multiple group levels by passing in a tuple that specifies a value for each index column. For example, if a grouping is based on the `'Partner'` and `'Trade Flow'` columns, the argument of `get_group` has to be a partner/flow pair, like `('France', 'Import')` to  get all rows associated with imports from France.

# %%
GROUPING_PARTNERFLOW = ['Partner','Trade Flow']
groups = milk_countries.groupby(GROUPING_PARTNERFLOW)

GROUP_PARTNERFLOW= ('France','Imports')
groups.get_group( GROUP_PARTNERFLOW )
# Out:
#       Year  Period Trade Flow        Reporter Partner  \
# 15    2014  201401    Imports  United Kingdom  France
# 68    2014  201402    Imports  United Kingdom  France
# 120   2014  201403    Imports  United Kingdom  France
# 171   2014  201404    Imports  United Kingdom  France
# 223   2014  201405    Imports  United Kingdom  France
# 273   2014  201406    Imports  United Kingdom  France
# 327   2014  201407    Imports  United Kingdom  France
# 370   2014  201408    Imports  United Kingdom  France
# 416   2014  201409    Imports  United Kingdom  France
# 466   2014  201410    Imports  United Kingdom  France
# 514   2014  201411    Imports  United Kingdom  France
# 565   2014  201412    Imports  United Kingdom  France
# 626   2014  201401    Imports  United Kingdom  France
# 696   2014  201402    Imports  United Kingdom  France
# 760   2014  201403    Imports  United Kingdom  France
# 830   2014  201404    Imports  United Kingdom  France
# 901   2014  201405    Imports  United Kingdom  France
# 970   2014  201406    Imports  United Kingdom  France
# 1048  2014  201407    Imports  United Kingdom  France
# 1121  2014  201408    Imports  United Kingdom  France
# 1193  2014  201409    Imports  United Kingdom  France
# 1271  2014  201410    Imports  United Kingdom  France
# 1354  2014  201411    Imports  United Kingdom  France
# 1425  2014  201412    Imports  United Kingdom  France
#
#                                               Commodity Commodity Code  \
# 15    Milk and cream, neither concentrated nor sweet...           0401
# 68    Milk and cream, neither concentrated nor sweet...           0401
# 120   Milk and cream, neither concentrated nor sweet...           0401
# 171   Milk and cream, neither concentrated nor sweet...           0401
# 223   Milk and cream, neither concentrated nor sweet...           0401
# 273   Milk and cream, neither concentrated nor sweet...           0401
# 327   Milk and cream, neither concentrated nor sweet...           0401
# 370   Milk and cream, neither concentrated nor sweet...           0401
# 416   Milk and cream, neither concentrated nor sweet...           0401
# 466   Milk and cream, neither concentrated nor sweet...           0401
# 514   Milk and cream, neither concentrated nor sweet...           0401
# 565   Milk and cream, neither concentrated nor sweet...           0401
# 626           Milk and cream, concentrated or sweetened           0402
# 696           Milk and cream, concentrated or sweetened           0402
# 760           Milk and cream, concentrated or sweetened           0402
# 830           Milk and cream, concentrated or sweetened           0402
# 901           Milk and cream, concentrated or sweetened           0402
# 970           Milk and cream, concentrated or sweetened           0402
# 1048          Milk and cream, concentrated or sweetened           0402
# 1121          Milk and cream, concentrated or sweetened           0402
# 1193          Milk and cream, concentrated or sweetened           0402
# 1271          Milk and cream, concentrated or sweetened           0402
# 1354          Milk and cream, concentrated or sweetened           0402
# 1425          Milk and cream, concentrated or sweetened           0402
#
#       Trade Value (US$)
# 15              1522872
# 68              1444455
# 120             1414291
# 171             1912257
# 223             1638838
# 273             1449614
# 327             2096771
# 370             1474883
# 416             1259777
# 466             1483422
# 514             1720555
# 565             1958660
# 626             8020014
# 696             6494426
# 760             7545848
# 830             5917331
# 901             7183954
# 970             6948169
# 1048            6630456
# 1121            7051096
# 1193            8514848
# 1271            8638220
# 1354            7938295
# 1425            4749124

# %% [markdown]
# To find the leading partner for a particular commodity, group by commodity, get the desired group, and then sort the result.

# %%
groups = milk_countries.groupby(['Commodity Code'])
groups.get_group('0402').sort_values("Trade Value (US$)", ascending=False).head()
# Out:
#      Year  Period Trade Flow        Reporter  Partner  \
# 954  2014  201406    Exports  United Kingdom  Algeria
# 880  2014  201405    Exports  United Kingdom  Algeria
# 811  2014  201404    Exports  United Kingdom  Algeria
# 841  2014  201404    Exports  United Kingdom  Ireland
# 773  2014  201403    Exports  United Kingdom  Ireland
#
#                                      Commodity Commodity Code  \
# 954  Milk and cream, concentrated or sweetened           0402
# 880  Milk and cream, concentrated or sweetened           0402
# 811  Milk and cream, concentrated or sweetened           0402
# 841  Milk and cream, concentrated or sweetened           0402
# 773  Milk and cream, concentrated or sweetened           0402
#
#      Trade Value (US$)
# 954           22411564
# 880           19656679
# 811           14875816
# 841           11712344
# 773           11015471

# %% [markdown]
# ### Task
#
# Using your own data set from Exercise 1, try to group the data in a variety of ways, finding the most significant trade partner in each case:
#
# - by commodity, or commodity code
# - by trade flow, commodity and year.

# %%
LOCATION='comtrade_flowers_kenya_monthly_20.csv'

# %%
# LOCATION = 'http://comtrade.un.org//api/get?max=5000&type=C&freq=M&px=HS&ps=2020&r=404&p=all&rg=1%2C2&cc=0603%2C0402&fmt=csv'

# %%
flowers = pd.read_csv(LOCATION, dtype={'Commodity Code':str, 'Reporter Code':str})
flowers.head(3)
# Out:
#   Classification  Year  Period Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             HS  2020  202008  August 2020                4             0
# 1             HS  2020  202006    June 2020                4             0
# 2             HS  2020  202006    June 2020                4             0
#
#    Trade Flow Code Trade Flow Reporter Code Reporter  ...  Qty  \
# 0                1    Imports           404    Kenya  ...  NaN
# 1                2    Exports           404    Kenya  ...  NaN
# 2                2    Exports           404    Kenya  ...  NaN
#
#    Alt Qty Unit Code Alt Qty Unit  Alt Qty  Netweight (kg)  Gross weight (kg)  \
# 0                NaN          NaN      NaN              22                NaN
# 1                NaN          NaN      NaN         8386230                NaN
# 2                NaN          NaN      NaN             412                NaN
#
#    Trade Value (US$)  CIF Trade Value (US$)  FOB Trade Value (US$)  Flag
# 0                 69                    NaN                    NaN     0
# 1           33686647                    NaN                    NaN     0
# 2                936                    NaN                    NaN     0
#
# [3 rows x 35 columns]

# %%
COLUMNS = ['Year', 'Period','Trade Flow','Reporter', 'Partner', 'Commodity','Commodity Code','Trade Value (US$)']
flowers = flowers[COLUMNS]

# %%
flowers_world = flowers[flowers['Partner'] == 'World']
flowers_countries = flowers[flowers['Partner'] != 'World']

# %%
flowers_countries.to_csv('countryflowers.csv', index=False)

# %%
load_test = pd.read_csv('countryflowers.csv', dtype={'Commodity Code':str, 'Reporter Code':str})
load_test.head(5)
# Out:
#    Year  Period Trade Flow Reporter                   Partner  \
# 0  2020  202008    Imports    Kenya                    Zambia
# 1  2020  202006    Exports    Kenya                    Rwanda
# 2  2020  202006    Exports    Kenya  United States of America
# 3  2020  202006    Exports    Kenya               Switzerland
# 4  2020  202006    Exports    Kenya                    France
#
#                                            Commodity Commodity Code  \
# 0  Flowers; cut flowers and flower buds of a kind...           0603
# 1  Flowers; cut flowers and flower buds of a kind...           0603
# 2  Flowers; cut flowers and flower buds of a kind...           0603
# 3  Flowers; cut flowers and flower buds of a kind...           0603
# 4  Flowers; cut flowers and flower buds of a kind...           0603
#
#    Trade Value (US$)
# 0                 69
# 1                936
# 2              64186
# 3             811991
# 4             390820

# %%
load_test=pd.read_csv('countryflowers.csv', dtype={'Commodity Code':str}, encoding = "ISO-8859-1")
load_test.head()
# Out:
#    Year  Period Trade Flow Reporter                   Partner  \
# 0  2020  202008    Imports    Kenya                    Zambia
# 1  2020  202006    Exports    Kenya                    Rwanda
# 2  2020  202006    Exports    Kenya  United States of America
# 3  2020  202006    Exports    Kenya               Switzerland
# 4  2020  202006    Exports    Kenya                    France
#
#                                            Commodity Commodity Code  \
# 0  Flowers; cut flowers and flower buds of a kind...           0603
# 1  Flowers; cut flowers and flower buds of a kind...           0603
# 2  Flowers; cut flowers and flower buds of a kind...           0603
# 3  Flowers; cut flowers and flower buds of a kind...           0603
# 4  Flowers; cut flowers and flower buds of a kind...           0603
#
#    Trade Value (US$)
# 0                 69
# 1                936
# 2              64186
# 3             811991
# 4             390820

# %%
flowers_imports = flowers[flowers['Trade Flow'] == 'Imports']
flowers_countries_imports = flowers_countries[flowers_countries['Trade Flow'] == 'Imports']
flowers_world_imports=flowers_world[flowers_world['Trade Flow'] == 'Imports']

# %%
flowersImportsInJanuary2020 = flowers_countries_imports[flowers_countries_imports['Period'] == 202001]
flowersImportsInJanuary2020.sort_values('Trade Value (US$)',ascending=False).head(10)
# Out:
#      Year  Period Trade Flow Reporter      Partner  \
# 893  2020  202001    Imports    Kenya  Netherlands
#
#                                              Commodity Commodity Code  \
# 893  Flowers; cut flowers and flower buds of a kind...           0603
#
#      Trade Value (US$)
# 893               2202

# %%
flowers_exports = flowers[flowers['Trade Flow'] == 'Exports']
flowers_countries_exports = flowers_countries[flowers_countries['Trade Flow'] == 'Exports']
flowers_world_exports=flowers_world[flowers_world['Trade Flow'] == 'Exports']

# %%
flowersExportsInFebruary2020 = flowers_countries_exports[flowers_countries_exports['Period'] == 202002]
flowersExportsInFebruary2020.sort_values('Trade Value (US$)',ascending=False).head(10)
# Out:
#      Year  Period Trade Flow Reporter               Partner  \
# 737  2020  202002    Exports    Kenya           Netherlands
# 774  2020  202002    Exports    Kenya        United Kingdom
# 729  2020  202002    Exports    Kenya    Russian Federation
# 741  2020  202002    Exports    Kenya               Germany
# 692  2020  202002    Exports    Kenya                Norway
# 702  2020  202002    Exports    Kenya             Australia
# 769  2020  202002    Exports    Kenya  United Arab Emirates
# 731  2020  202002    Exports    Kenya          Saudi Arabia
# 690  2020  202002    Exports    Kenya           Switzerland
# 693  2020  202002    Exports    Kenya                France
#
#                                              Commodity Commodity Code  \
# 737  Flowers; cut flowers and flower buds of a kind...           0603
# 774  Flowers; cut flowers and flower buds of a kind...           0603
# 729  Flowers; cut flowers and flower buds of a kind...           0603
# 741  Flowers; cut flowers and flower buds of a kind...           0603
# 692  Flowers; cut flowers and flower buds of a kind...           0603
# 702  Flowers; cut flowers and flower buds of a kind...           0603
# 769  Flowers; cut flowers and flower buds of a kind...           0603
# 731  Flowers; cut flowers and flower buds of a kind...           0603
# 690  Flowers; cut flowers and flower buds of a kind...           0603
# 693  Flowers; cut flowers and flower buds of a kind...           0603
#
#      Trade Value (US$)
# 737           30593127
# 774           13994026
# 729            3150555
# 741            3131723
# 692            2627742
# 702            2108650
# 769            2005308
# 731            1809338
# 690             987509
# 693             921073

# %%
groups = flowers_countries.groupby('Trade Flow')

# %%
groups.get_group('Exports').head()
# Out:
#    Year  Period Trade Flow Reporter                   Partner  \
# 2  2020  202006    Exports    Kenya                    Rwanda
# 3  2020  202006    Exports    Kenya  United States of America
# 4  2020  202006    Exports    Kenya               Switzerland
# 5  2020  202006    Exports    Kenya                    France
# 6  2020  202006    Exports    Kenya           Other Asia, nes
#
#                                            Commodity Commodity Code  \
# 2  Flowers; cut flowers and flower buds of a kind...           0603
# 3  Flowers; cut flowers and flower buds of a kind...           0603
# 4  Flowers; cut flowers and flower buds of a kind...           0603
# 5  Flowers; cut flowers and flower buds of a kind...           0603
# 6  Flowers; cut flowers and flower buds of a kind...           0603
#
#    Trade Value (US$)
# 2                936
# 3              64186
# 4             811991
# 5             390820
# 6                912

# %%
GROUPING_COMMFLOW = ['Commodity Code','Trade Flow']

groups = flowers_countries.groupby(GROUPING_COMMFLOW)
groups.groups.keys()
# Out:
# dict_keys([('0603', 'Exports'), ('0603', 'Imports')])

# %%
GROUPING_PARTNERFLOW = ['Partner','Trade Flow']
groups = flowers_countries.groupby(GROUPING_PARTNERFLOW)

GROUP_PARTNERFLOW= ('United Kingdom','Exports')
groups.get_group( GROUP_PARTNERFLOW )
# Out:
#      Year  Period Trade Flow Reporter         Partner  \
# 44   2020  202006    Exports    Kenya  United Kingdom
# 144  2020  202012    Exports    Kenya  United Kingdom
# 249  2020  202001    Exports    Kenya  United Kingdom
# 316  2020  202008    Exports    Kenya  United Kingdom
# 329  2020  202005    Exports    Kenya  United Kingdom
# 441  2020  202010    Exports    Kenya  United Kingdom
# 500  2020  202011    Exports    Kenya  United Kingdom
# 550  2020  202007    Exports    Kenya  United Kingdom
# 682  2020  202004    Exports    Kenya  United Kingdom
# 774  2020  202002    Exports    Kenya  United Kingdom
# 831  2020  202003    Exports    Kenya  United Kingdom
#
#                                              Commodity Commodity Code  \
# 44   Flowers; cut flowers and flower buds of a kind...           0603
# 144  Flowers; cut flowers and flower buds of a kind...           0603
# 249  Flowers; cut flowers and flower buds of a kind...           0603
# 316  Flowers; cut flowers and flower buds of a kind...           0603
# 329  Flowers; cut flowers and flower buds of a kind...           0603
# 441  Flowers; cut flowers and flower buds of a kind...           0603
# 500  Flowers; cut flowers and flower buds of a kind...           0603
# 550  Flowers; cut flowers and flower buds of a kind...           0603
# 682  Flowers; cut flowers and flower buds of a kind...           0603
# 774  Flowers; cut flowers and flower buds of a kind...           0603
# 831  Flowers; cut flowers and flower buds of a kind...           0603
#
#      Trade Value (US$)
# 44             7431869
# 144           12087907
# 249           10442336
# 316           10160604
# 329            7548314
# 441            9728942
# 500            9835308
# 550            9322490
# 682            6160190
# 774           13994026
# 831           11778608

# %%
groups = flowers_countries.groupby(['Commodity Code'])
groups.get_group('0603').sort_values("Trade Value (US$)", ascending=False).head()
# Out:
#      Year  Period Trade Flow Reporter      Partner  \
# 737  2020  202002    Exports    Kenya  Netherlands
# 92   2020  202012    Exports    Kenya  Netherlands
# 451  2020  202010    Exports    Kenya  Netherlands
# 226  2020  202001    Exports    Kenya  Netherlands
# 816  2020  202003    Exports    Kenya  Netherlands
#
#                                              Commodity Commodity Code  \
# 737  Flowers; cut flowers and flower buds of a kind...           0603
# 92   Flowers; cut flowers and flower buds of a kind...           0603
# 451  Flowers; cut flowers and flower buds of a kind...           0603
# 226  Flowers; cut flowers and flower buds of a kind...           0603
# 816  Flowers; cut flowers and flower buds of a kind...           0603
#
#      Trade Value (US$)
# 737           30593127
# 92            27239029
# 451           25991010
# 226           25588432
# 816           23799740

# %% [markdown]
# Netherlands is a significant trade partner as both an importer and also the sole exporter of flowers to Kenya
