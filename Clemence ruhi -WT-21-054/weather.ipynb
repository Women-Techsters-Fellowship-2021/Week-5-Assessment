# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd
from datetime import datetime

# %%
delhi = pd.read_csv('Delhi_DEL_2014.csv', skipinitialspace=True)
delhi.head()
# Out:
#        Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0  2014-1-1                -4                 -7                -9
# 1  2014-1-2                -1                 -4                -8
# 2  2014-1-3                 1                 -3                -8
# 3  2014-1-4                -1                 -2                -3
# 4  2014-1-5                -1                 -3                -6
#
#    Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# 0          -9             -10            -11            82             70
# 1          -6              -8            -11            75             69
# 2          -4              -6            -10            84             72
# 3          -4              -5             -6            80             74
# 4          -4              -6             -8            93             79
#
#    Min Humidity  ...  Max VisibilityKm  Mean VisibilityKm  Min VisibilitykM  \
# ...

# %%
# %matplotlib inline

# %%
delhi['Max Wind SpeedKm/h'].plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
delhi['Max Wind SpeedKm/h'].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
delhi[['Max Wind SpeedKm/h', 'Mean Wind SpeedKm/h']].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
delhi[['Min TemperatureC', 'Mean TemperatureC']].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
delhi = delhi.rename(columns={'WindDirDegrees<br />' : 'WindDirDegrees'})

# %%
delhi['WindDirDegrees'] = delhi['WindDirDegrees'].str.rstrip('<br />')

# %%
delhi['WindDirDegrees'] = delhi['WindDirDegrees'].astype('float64')

# %%
delhi['Date'] = pd.to_datetime(delhi['Date'])
delhi.index = delhi['Date']
delhi.head(2)
# Out:
#                  Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# Date
# 2014-01-01 2014-01-01                -4                 -7                -9
# 2014-01-02 2014-01-02                -1                 -4                -8
#
#             Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  \
# Date
# 2014-01-01          -9             -10            -11            82
# 2014-01-02          -6              -8            -11            75
#
#             Mean Humidity  Min Humidity  ...  Max VisibilityKm  \
# Date                                     ...
# 2014-01-01             70            58  ...                 2
# 2014-01-02             69            53  ...                 3
#
#             Mean VisibilityKm  Min VisibilitykM  Max Wind SpeedKm/h  \
# Date
# 2014-01-01                  2                 2                   6
# 2014-01-02                  2                 2                   6
#
# ...

# %%
delhi.dropna()
# Out:
#                  Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# Date
# 2014-09-29 2014-09-29                26                 19                13
#
#             Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  \
# Date
# 2014-09-29          15              10             -2           100
#
#             Mean Humidity  Min Humidity  ...  Max VisibilityKm  \
# Date                                     ...
# 2014-09-29             61            13  ...                10
#
#             Mean VisibilityKm  Min VisibilitykM  Max Wind SpeedKm/h  \
# Date
# 2014-09-29                 10                10                  32
#
#             Mean Wind SpeedKm/h  Max Gust SpeedKm/h  Precipitationmm  \
# Date
# 2014-09-29                    6                42.0             0.51
#
#             CloudCover  Events  WindDirDegrees
# Date
# 2014-09-29         4.0    Rain           338.0
#
# [1 rows x 23 columns]

# %%
delhi.dtypes
# Out:
# Date                          datetime64[ns]
# Max TemperatureC                       int64
# Mean TemperatureC                      int64
# Min TemperatureC                       int64
# Dew PointC                             int64
# MeanDew PointC                         int64
# Min DewpointC                          int64
# Max Humidity                           int64
# Mean Humidity                          int64
# Min Humidity                           int64
# Max Sea Level PressurehPa              int64
# Mean Sea Level PressurehPa             int64
# Min Sea Level PressurehPa              int64
# Max VisibilityKm                       int64
# Mean VisibilityKm                      int64
# Min VisibilitykM                       int64
# Max Wind SpeedKm/h                     int64
# Mean Wind SpeedKm/h                    int64
# Max Gust SpeedKm/h                   float64
# Precipitationmm                      float64
# CloudCover                           float64
# ...

# %%
delhi['WindDirDegrees'] = delhi['WindDirDegrees'].astype('int64')

# %%
delhi[delhi['WindDirDegrees'] > 350]
# Out:
#                  Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# Date
# 2014-02-02 2014-02-02                -3                 -7               -10
# 2014-02-03 2014-02-03                -4                 -9               -13
# 2014-05-07 2014-05-07                31                 22                13
# 2014-05-12 2014-05-12                27                 20                13
# 2014-07-01 2014-07-01                31                 24                17
# 2014-07-14 2014-07-14                33                 27                19
# 2014-08-09 2014-08-09                37                 28                18
# 2014-08-13 2014-08-13                36                 28                20
# 2014-08-23 2014-08-23                35                 27                19
# 2014-09-01 2014-09-01                33                 26                18
#
#             Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  \
# Date
# ...

# %%
delhi['Date'] = pd.to_datetime(delhi['Date'])
delhi.dtypes
# Out:
# Date                          datetime64[ns]
# Max TemperatureC                       int64
# Mean TemperatureC                      int64
# Min TemperatureC                       int64
# Dew PointC                             int64
# MeanDew PointC                         int64
# Min DewpointC                          int64
# Max Humidity                           int64
# Mean Humidity                          int64
# Min Humidity                           int64
# Max Sea Level PressurehPa              int64
# Mean Sea Level PressurehPa             int64
# Min Sea Level PressurehPa              int64
# Max VisibilityKm                       int64
# Mean VisibilityKm                      int64
# Min VisibilitykM                       int64
# Max Wind SpeedKm/h                     int64
# Mean Wind SpeedKm/h                    int64
# Max Gust SpeedKm/h                   float64
# Precipitationmm                      float64
# CloudCover                           float64
# ...

# %%
dates = delhi['Date']
start = datetime(2014, 12, 8)
end = datetime(2014, 12, 12)
delhi[(dates >= start) & (dates <= end)]
# Out:
#                  Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# Date
# 2014-12-08 2014-12-08                 9                  7                 4
# 2014-12-09 2014-12-09                11                  7                 3
# 2014-12-10 2014-12-10                 8                  5                 2
# 2014-12-11 2014-12-11                11                  6                 1
# 2014-12-12 2014-12-12                 9                  6                 1
#
#             Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  \
# Date
# 2014-12-08           2               1             -1            71
# 2014-12-09           4               2             -1            81
# 2014-12-10           4               3              1            93
# 2014-12-11           6               3              0            93
# 2014-12-12           2               1              0            92
#
#             Mean Humidity  Min Humidity  ...  Max VisibilityKm  \
# ...

# %%
delhi['Max Wind SpeedKm/h'].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
summer = delhi.loc[datetime(2014,6,1) : datetime(2014,8,31)]

# %%
summer[summer['Mean TemperatureC'] >= 25]
# Out:
#                  Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# Date
# 2014-06-20 2014-06-20                36                 26                16
# 2014-06-21 2014-06-21                37                 27                17
# 2014-06-22 2014-06-22                37                 27                17
# 2014-06-23 2014-06-23                33                 26                18
# 2014-06-24 2014-06-24                31                 25                19
# ...               ...               ...                ...               ...
# 2014-08-27 2014-08-27                36                 28                19
# 2014-08-28 2014-08-28                38                 27                16
# 2014-08-29 2014-08-29                38                 28                18
# 2014-08-30 2014-08-30                35                 27                18
# 2014-08-31 2014-08-31                33                 26                18
#
# ...

# %%
# %matplotlib inline

# %%
summer['Mean TemperatureC'].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
summer[['Mean TemperatureC', 'Precipitationmm']].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
july = summer.loc[datetime(2014,7,1) : datetime(2014,7,31)]
july[['Mean TemperatureC', 'Precipitationmm']].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
spring = delhi.loc[datetime(2014,3,1) : datetime(2014,5,30)]

# %%
# %matplotlib inline

# %%
spring['Mean Humidity'].plot(grid=True, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>
